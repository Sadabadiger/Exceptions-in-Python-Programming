# %% [markdown]
# # Exception
# - As human beings, we commit several errors.
# - A sotware developer is also a human being and hence prone to commit errors either in design of the sofware or writing in code
# - The errors in the software are called 'bugs' and the process of removing them is called 'debugging'

# %% [markdown]
# # Errors in the python programs
# - In general, we can classify errors in a program into one of these three types
#     1. Compiler-time errors
#     2. Runtime errors
#     3. Logical errors

# %% [markdown]
# # Compile-Time Errors
# - These are the syntactical errors found in the code, due to which a program fails to compile.
# - for example forgetting a colon in the statement like if, while, for, def etc.
# - such errors are detected by python compiler and the line number along with error description is displayed by the python compiler.

# %%
# A Python program to understand the compile-time error 
x=10
if x%2==0:
    print(x,'is divisible by 2')
# Out:
# 10 is divisible by 2

# %%
# A Python program to demonstrate compile-time error

# %% [markdown]
# # Runtime errors
# - When PVM cannot execute the byte code, it flags runtime error
# - for example, insufficient memory to store something or inability of the PVM to execute some statement come under runtime errors.
# - Runtime errors are not detected by python compiler
# - They are detected by the PVM, only at run time

# %%
# A Python programs to understand runtime errors
def concat(a,b):
    print(a+b)
    
#call cancat()
concat('Hai','vijay')
# Out:
# Haivijay

# %%
# A Python program to demonstrate runtime error
animal=['dog','cat','horse','donkey']
print(animal[3])
# Out:
# donkey

# %% [markdown]
# # Logical Errors
# - These errors depicts flaws in the logic of the program.
# - The programmer might be using a wrong formula or the design of the program itself is wrong
# - Logical errors are not detected either by python compiler or PVM
# - The programmer is solely responsible for them.
# - In the following program, the programmer wants to calculate increment salary of an employee, but he gets worng output since he uses wrong formula

# %%
# A Python program to increment the salary of an employee by 15%
def increment(sal):
    sal=sal+sal*15/100
    return sal

sal=increment(5000.00)
print('incremented salary=%0.2f' %sal)
# Out:
# incremented salary=5750.00

# %% [markdown]
# - compile time errors and logical errors can be eliminated by the programmer by modifying the program source code.
# - In case of runtime errors, when the programmer knows which type of error ocuures, he has to handle them using exception handling mechanism
# - The runtime error can be handled by the programmer are called **exceptions**.
# - Before discussing exception handling mechanism, we will first understand what type of harm an exception can cause.

# %%
# A Python program to undertsand the effect of an exception 

#open a file
f=open("myfile",'w')

#do some processing on the file
#accept a, b values, store the result of a/b into the file
try:
    a, b=[int(x) for x in input("Enter two numbers: ").split()]
    c=a/b
    f.write("writing %d into myfile" %c)

    #close the file
    f.close()
    print('file closed')
    
except ZeroDivisionError:
    print("Division by zero happened")
# Out:
# Enter two numbers: 10 2
# file closed

# %% [markdown]
# **So when there is an error in a program, due to its sudden termination, the following things can be suspected**
# - The important data in the file or database used in the programmer may be lost
# - The software may be corrupted
# - The program abruptly terminates giving error message to the user making the user losing the trust in the software
#
# **Hence it is duty of the programmer to handle the error. programmer canot hanlde all errors. We can hanlde only some types of errors which are called exceptions**

# %% [markdown]
# # Exceptions
# - An exception is run time error which can be handled by the programmer
# - That means if the programmer can guess an error in the program and can do something to eliminate the harm caused by that error then it is called 'exception'
# - if the programmer cannot do anything in case of an error, then it is called an 'error' and not an exception
# - All eceptions are represented as classes in Python. The exceptions which are already available in python are called 'built-in' exceptions.
# - The below figure shows important classes available in Exception hierarchy
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exception Handling
#
# **To handle exceptions, the programmer should perform the following three steps**
#
# **Step1** : The programmer should observe the statements in his program where there may be possibility of exceptions. such statements should be written inside a 'try' block. A try block looks like as follows:
#
#     try:
#          statements
#
# **Step2** : The programmer shoul write the 'except' block where he should display the exception details to the user. this helpsthe user to understand that there is some error in the program. The programmer should also display a message regarding what can be done to avoid this error. except block looks like as follows
#
#     except exceptionname:
#         statements   #These statements from handler
#
# **Step3** : Lastly the programmer should perform cleanup actions like closing the files and terminating any other process which are running. Finally block looks like as follows
#
#     finally:
#         statements
#
#    specialty of **finally** block is that the statement inside the finally block executes irrespective of whether there is an exception or not. This ensure that all the opened files are properly closed and all the running processes are properly terminated. So the data in the files will not corrupted and the user is at the safe-side

# %%
# A python program to handle the ZeroDivisionError exception
try:
    f=open("myfile",'w')
    a,b=[int(x) for x in input("Enter two numbers").split()]
    c=a/b
    f.write("writing %d into myfile" %c)
except ZeroDivisionError:
           print("Division by zero happen")
           print("Please do not enter 0 in input")
finally:
        f.close()
        print("File closed")
# Out:
# Enter two numbers10 0
# Division by zero happen
# Please do not enter 0 in input
# File closed

# %% [markdown]
# **The complete exception handling syntax will be in the following format**
#
#
#         try:
#             statements
#         except Exception1:
#             handler1
#         except Exception2:
#             hanlder2
#         else:
#             statements
#         finally:
#             statements
#
# **The following points are noteworthy**
# - A single try block can be followed by several except block
# - Mutiple except block can be used to handle multiple exceptions
# - we cannot write except blocks without a try block
# - we can write try block without any exceptions
# - Else block and finally blocks are not compulsory
# - when there is no exception, else block is executed after try block
# - Finally block is always executed

# %% [markdown]
# # Types of Exceptions
#
# ![scan_filter_1621420390143.jpg](attachment:scan_filter_1621420390143.jpg)

# %% [markdown]
# ![scan_filter_1621420476135.jpg](attachment:scan_filter_1621420476135.jpg)

# %%
# A Python program to handle syntax error given by eval() function
try:
    date=eval(input("Enter date: "))
except SyntaxError:
    print('Invalid date entered')
else:
    print('You entered: ', date)
# Out:
# Enter date: 2021,10b,11
# Invalid date entered

# %% [markdown]
# # The assert Statment
# - The assert statement is useful to ensure that a given condition is True. if it is not true it raises AssertionError. The syntax is as follows
#
#         assert condition, message
#
# - If the condition is False, then the exception by the name Assertion is raised along with the message written in the assert statement

# %%
# A Python using the assert statement and catching assertion error
try:
    x=int(input('Enter a number between 5 and 10: '))
    assert x>=5 and x<=10 
    print("The number entered: ",x)
except AssertionError:
    print("The condition is not fulfilled")
# Out:
# Enter a number between 5 and 10: 11
# The condition is not fulfilled
